# %%
# !pip install seaborn

# %%
import seaborn as sns
import pandas as pd

# %%
diamonds_df = pd.read_csv(r"C:\Users\User\Desktop\POSTGRADUATE_FIA\DATA_ANALITYCS_CCT\2 SEMESTER\MachLearnBus_HDipData_Feb22_FT\diamonds.csv")

# %%
diamonds_df.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds_df.info()
#Non-Null (non of this have missing values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds_df.hist(column="carat")
# Out:
# array([[<AxesSubplot:title={'center':'carat'}>]], dtype=object)

# %%
diamonds_df.hist(column="carat", bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'carat'}>]], dtype=object)

# %%
sns.distplot(diamonds_df.carat)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='carat', ylabel='Density'>

# %%
sns.distplot(diamonds_df.carat, kde=False);
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(diamonds_df.carat, kde=False, bins=100);

# %%
sns.distplot(diamonds_df.price, kde=False, bins=100);

# %%
import numpy as np

# %%
sns.distplot(np.log(diamonds_df.price), kde=False);

# %%
diamonds_df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds_df["color"].nunique()
# Out:
# 7

# %%
cut_count_table = pd.crosstab(index=diamonds_df['cut'],columns='count')

# %%
cut_count_table
# Out:
# col_0      count
# cut
# Fair        1610
# Good        4906
# Ideal      21551
# Premium    13791
# Very Good  12082

# %%
cut_count_table.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='cut'>

# %%
sns.catplot("cut",data=diamonds_df,kind="count")
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.catplot("cut",data=diamonds_df,kind="count",color="b");
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from numpy import median, mean

# %%
ax = sns.barplot(x="cut",y="price",data=diamonds_df,
                estimator=mean,
                ci="sd")

# %%
ax = sns.barplot(x="cut",y="price",data=diamonds_df,
                estimator=mean,
                order=["Ideal","Good","Very Good","Fair","Premium"],
                ci=68)

# %%
ax = sns.barplot(x="cut",y="price",hue="color",data=diamonds_df)

# %%
ax = sns.barplot(x="cut",y="price",hue="color",data=diamonds_df)
ax.legend(loc="upper right",ncol=4)

# %%
ax = sns.barplot(x="cut",y="price",hue="color",data=diamonds_df)
ax.legend(loc="upper right",ncol=4)
ax.set_xlabel("Cut",fontdict = {"fontsize":15})
ax.set_xlabel("Price",fontdict = {"fontsize":15})
# Out:
# Text(0.5, 0, 'Price')

# %%
ax = sns.barplot(x="cut",y="price",hue="color",data=diamonds_df)
ax.legend(loc="upper right",ncol=4)
ax.set_xlabel("Cut",fontdict = {"fontsize":15})
ax.set_xlabel("Price",fontdict = {"fontsize":15})
ax.set(title="Diamonds Price Vs Cut")
# Out:
# [Text(0.5, 1.0, 'Diamonds Price Vs Cut')]

# %%
ax = sns.barplot(x="cut",y="price",hue="color",data=diamonds_df)
ax.legend(loc="upper right",ncol=4)
ax.set_xlabel("Cut",fontdict = {"fontsize":15})
ax.set_xlabel("Price",fontdict = {"fontsize":15})
ax.set_xticklabels(ax.get_xticklabels(), fontsize=13, rotation=30) 

ax.set(title="Diamonds Price Vs Cut")
# Out:
# [Text(0.5, 1.0, 'Diamonds Price Vs Cut')]
